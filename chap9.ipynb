# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # 9章　プロットと可視化
# ## 9.1　Matplotlib APIの概要

# %%
# 一次元のndarrayを渡して直線をプロットする
data = np.arange(10)
plt.plot(data)
# Out:
# [&lt;matplotlib.lines.Line2D at 0x1be770519a0&gt;]
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ### 9.1.1 図とサブプロット
# - Matplotlibのプロット（可視化）機能はFigureオブジェクトに含まれている
# - figureオブジェクトにサブプロット（1つのグラフを描く領域）を作る
# - Jupyter Notebookでは、各セルの実行評価後、プロットがリセットされるため、一つのセル内で一連のプロットコマンドを完結させる必要がある
# - add_subplot(x, y, n)でx行y列のサブプロットn番目を選択する
# - add_subplot()で返されるAxesSubplotオブジェクトのインスタンスメソッドを呼び出してプロット

# %%
# figureオブジェクトのインスタンス化
fig = plt.figure()
# add_subplot(x, y, n)でx行y列のサブプロットのn個目の領域を選択する
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# plotを実行すると最後に指定していたサブプロットに描画される
plt.plot([1.5, 3.5, -2, 1.6])

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# plotを実行すると最後に指定していたサブプロットに描画される
plt.plot(np.random.randn(50).cumsum(), 'k--') # 'k--'は線種っ指定オプション

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

plt.plot(np.random.randn(50).cumsum(), 'k--')

#AxesSubplotオブジェクトのインスタンスメソッドでプロット
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
# Out:
# &lt;matplotlib.collections.PathCollection at 0x1be7a45abb0&gt;
# &lt;Figure size 432x288 with 3 Axes&gt;

# %% [markdown]
# - subplots()でfigureオブジェクトを生成し、格子状のサブロットを要素に持つndarrayを作成できる
# - AxesSubplotをインデックスで指定できる
# - オプションで、行列の数やxy軸の目盛りを共有などを指定できる＞p283の表を参照

# %%
fig, axes = plt.subplots(2, 3)

# %% [markdown]
# #### 9.1.1.1 サブプロットのまわりの空白を調整する
# - サブプロットのまわりの余白は相対的な比率指定なので、動的に調整される
# - figureオブジェクトのsubplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)でスペースの割合を指定できる

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True) # sharex, shareyで目盛りを共有する
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0) # サブプロット間の幅と高さのを0パーセント指定

# %% [markdown]
# ### 9.1.2 色、マーカー、線種
# - Matplotlibｍの主要な関数plot関数
# - 基本的な使い方は、x, y座標の配列を引数に渡す
# - 文字列で色や線種を指定する
#   - ax.plot(x, y, 'g--')
#   - ax.plot(x,y, linestyle='--', color='g')のように明示的にも指定できる

# %%
# マーカーを指定するとデータポイントを目立たせることができる
plt.plot(np.random.randn(30).cumsum(), 'ko--')
# plt.plot(np.random.randn(30).cumsum(), color='k', linestyle='dashed', marker='o')
# Out:
# [&lt;matplotlib.lines.Line2D at 0x2237454c820&gt;]
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')

# %%
# drawstyleオプションで階段のようなグラフにできる
plt.plot(data, 'k-',drawstyle='steps-post', label='steps-post')
# Out:
# [&lt;matplotlib.lines.Line2D at 0x22375fc42e0&gt;]
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-',drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')
# legendで各線の凡例を作成できる

# %% [markdown]
# ### 9.1.3 目盛り、ラベル、凡例

# %% [markdown]
# #### 9.1.3.1 タイトル、軸のラベル、目盛り、目盛りのラベルを設定する

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# set_xticksでデータのどこに目盛りを振るかを指定
ticks = ax.set_xticks([0, 250, 500, 750, 1000])

# set_xticklabelsで目盛りのラベルを指定、フォントや回転も
labelss = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                             rotation=30, fontsize='small')

# プロットのとx軸の名前を指定
ax.set_title('My first matplotlib plot with title')
ax.set_xlabel('Stages')

ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labelss = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                             rotation=30, fontsize='small')

# 軸クラス（AxesSubplot）はsetメソッドがあり一括してできる
props = {
    'title': 'My first matplotlib plot with title',
    'xlabel': 'Stages'
}
ax.set(**props)
ax.plot(np.random.randn(1000).cumsum())

# %% [markdown]
# - 上記ticksとlabelsは変数への代入が必要？なくても良い？

# %% [markdown]
# #### 9.1.3.2　凡例の追加
# - 各プロットのlabel引数で凡例名を指定できる
# - ax.legend()かplt.legend()で凡例を追加できる
# - locは凡例の位置を指定するオプション、bestを指定で最も邪魔にならない場所
# - 凡例に追加しない場合はラベルの指定をしないかlabel=_nolegend_と指定する

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'k--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'k.', label='thre')
ax.legend(loc='best')

# %% [markdown]
# ### 9.1.4　サブプロットへの注釈や描画

# %%
import matplotlib.dates as dates
from datetime import datetime

font_options = {'family': 'TakaoGothic'}
plt.rc('font', **font_options)

fig = fig.add_subplot(1, 1, 1)
data

# %% [markdown]
# ## 9.2　pandasとseabornのプロット関数
# - pandasは本体に可視化の標準メソッドが組み込まれている
# - seabornは可視化用のライブラリ
# ### 9.2.1　折れ線グラフ
# - pandasのSeriesやDataFrameのplot()は折れ線グラフ
# - デフォルトではインデックスがX軸にプロットされる
# - `use_index=False`を指定して無効化
# - 目盛り、範囲は`xticks`や`xlim`で調整可能（Y軸も同様）
# - その他オプションはp297 表9-3

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=list('ABCD'), index=np.arange(0, 100, 10))
df.plot()
# df.plot.line()と等価
# Out:
# <AxesSubplot:>
